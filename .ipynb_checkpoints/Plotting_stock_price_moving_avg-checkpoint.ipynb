# %%
import pandas as pd

# %%
aapl = pd.read_csv('AAPL.csv', parse_dates=['Date'])

# %%
aapl.head(5)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-10-20  148.699997  149.750000  148.119995  149.259995  148.428268
# 1 2021-10-21  148.809998  149.639999  147.869995  149.479996  148.647049
# 2 2021-10-22  149.690002  150.179993  148.639999  148.690002  147.861450
# 3 2021-10-25  148.679993  149.369995  147.619995  148.639999  147.811722
# 4 2021-10-26  149.330002  150.839996  149.009995  149.320007  148.487946
#
#      Volume
# 0  58418800
# 1  61421000
# 2  58883400
# 3  50720600
# 4  60893400

# %%
aapl['CloseWA'] = aapl['Close'].rolling(window=7).mean()

# %%
aapl
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2021-10-20  148.699997  149.750000  148.119995  149.259995  148.428268
# 1   2021-10-21  148.809998  149.639999  147.869995  149.479996  148.647049
# 2   2021-10-22  149.690002  150.179993  148.639999  148.690002  147.861450
# 3   2021-10-25  148.679993  149.369995  147.619995  148.639999  147.811722
# 4   2021-10-26  149.330002  150.839996  149.009995  149.320007  148.487946
# ..         ...         ...         ...         ...         ...         ...
# 247 2022-10-13  134.990005  143.589996  134.369995  142.990005  142.990005
# 248 2022-10-14  144.309998  144.520004  138.190002  138.380005  138.380005
# 249 2022-10-17  141.070007  142.899994  140.270004  142.410004  142.410004
# 250 2022-10-18  145.490005  146.699997  140.610001  143.750000  143.750000
# 251 2022-10-19  141.690002  144.949997  141.500000  143.860001  143.860001
#
#         Volume     CloseWA
# 0     58418800         NaN
# ...

# %%
#plotting the chart
import matplotlib.pyplot as plt
# %matplotlib inline

plot = aapl.plot(x='Date', y=['Close', 'CloseWA'],
                 kind='line', title='Plot of stock price')

#change legend
plt.legend(loc='lower left')

# %%
import plotly.express as px
fig = plt.figure()
ax = fig.add_subplot()

A = aapl['Date']
B = aapl[['Close', 'CloseWA']]

stock_line = plt.plot(A,B)


df = px.data.gapminder().query("continent=='Oceania'")

fig = px.line(df, x="year", y="lifeExp", color="country", title="layout.hovermode='x'")
fig.update_traces(mode="markers+lines", hovertemplate=None)
fig.update_layout(hovermode="x")

fig.show()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [39], line 10
#       7 stock_line = plt.plot(A,B)
#       9 #create hover annotation object
# ---> 10 ax.annotate(text='',
#      11             xy = (0.0),
#      12             xytext=(15,15), #distance from x,y
#      13             textcoords='offset points',
#      14             bbox={'boxstype': 'round', 'fc': 'w'},
#      15             arrowprops={'arrowstyle': '->'}
#      16            )
#      18 plt.grid()
#      19 plt.show()
#
# File /opt/miniconda3/envs/lighthouse/lib/python3.9/site-packages/matplotlib/axes/_axes.py:666, in Axes.annotate(self, text, xy, *args, **kwargs)
#     664 @docstring.dedent_interpd
#     665 def annotate(self, text, xy, *args, **kwargs):
# --> 666     a = mtext.Annotation(text, xy, *args, **kwargs)
#     667     a.set_transform(mtransforms.IdentityTransform())
# ...
