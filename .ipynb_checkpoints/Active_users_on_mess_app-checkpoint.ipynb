# %%
import pandas as pd

# %%
p2p = pd.read_csv('data/ddi_message_app_data.csv')

# %%
p2p.head()
# Out:
#          date  sender_id  receiver_id
# 0  2018-03-01          5            2
# 1  2018-03-01          8            6
# 2  2018-03-01          1            2
# 3  2018-03-01          4            8
# 4  2018-03-01          2            7

# %%
mar01 = p2p[p2p['date'] == '2018-03-01']
print(mar01.shape)
mar01.head(5)
# Out:
# (459, 3)
#          date  sender_id  receiver_id
# 0  2018-03-01          5            2
# 1  2018-03-01          8            6
# 2  2018-03-01          1            2
# 3  2018-03-01          4            8
# 4  2018-03-01          2            7

# %%
mar01.groupby('sender_id')['receiver_id'].nunique().reset_index()
# Out:
#    sender_id  receiver_id
# 0          1            9
# 1          2            9
# 2          3            9
# 3          4            9
# 4          5            9
# 5          6            9
# 6          7            8
# 7          8            9
# 8          9            9
# 9         10            9

# %%
mar01.groupby('sender_id')['receiver_id'].unique().reset_index()
# Out:
#    sender_id                   receiver_id
# 0          1  [2, 7, 10, 5, 9, 8, 4, 3, 6]
# 1          2  [7, 10, 8, 4, 3, 1, 5, 9, 6]
# 2          3  [6, 5, 7, 4, 10, 8, 2, 9, 1]
# 3          4  [8, 7, 3, 5, 1, 6, 2, 9, 10]
# 4          5  [2, 8, 4, 7, 9, 1, 3, 10, 6]
# 5          6  [2, 7, 9, 5, 10, 3, 8, 1, 4]
# 6          7     [1, 4, 3, 2, 10, 9, 8, 6]
# 7          8  [6, 7, 5, 4, 10, 9, 3, 2, 1]
# 8          9  [1, 8, 4, 3, 6, 7, 2, 10, 5]
# 9         10   [2, 7, 4, 9, 1, 5, 6, 3, 8]

# %%
mar01[mar01['sender_id'] == 1]
# Out:
#            date  sender_id  receiver_id
# 2    2018-03-01          1            2
# 8    2018-03-01          1            7
# 23   2018-03-01          1           10
# 27   2018-03-01          1            7
# 28   2018-03-01          1            5
# 32   2018-03-01          1            5
# 49   2018-03-01          1            5
# 61   2018-03-01          1           10
# 80   2018-03-01          1            9
# 102  2018-03-01          1           10
# 103  2018-03-01          1            7
# 104  2018-03-01          1           10
# 106  2018-03-01          1            8
# 109  2018-03-01          1            4
# 112  2018-03-01          1            8
# 123  2018-03-01          1            4
# 126  2018-03-01          1            4
# 127  2018-03-01          1           10
# 146  2018-03-01          1            4
# 160  2018-03-01          1            4
# 176  2018-03-01          1            4
# 178  2018-03-01          1           10
# ...
